# %%
import pandas as pd
df = pd.read_csv('classification_data.csv')
print(df.head())
# Out:
#    age  income  education marital_status purchased
# 0   25   50000  Bachelors         Single        No
# 1   32   60000    Masters        Married       Yes
# 2   45   80000        PhD        Married       Yes
# 3   22   40000  Bachelors         Single        No
# 4   35   58000    Masters        Married       Yes

# %%
print(df.isnull().sum())
print(df.describe())
# Out:
# age               0
# income            0
# education         0
# marital_status    0
# purchased         0
# dtype: int64
#              age        income
# count  10.000000     10.000000
# mean   34.400000  59600.000000
# std     8.934328  11432.896007
# min    22.000000  40000.000000
# 25%    28.250000  52500.000000
# 50%    33.500000  59000.000000
# 75%    39.500000  66500.000000
# max    50.000000  80000.000000

# %%
import matplotlib.pyplot as plt
df['purchased'].value_counts().plot(kind='bar')
plt.title('Target Variable Distribution')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %%
df['age'].plot(kind='hist', bins=10)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
df['education'].value_counts().plot(kind='bar')
plt.title('Education Distribution')
plt.show()

# %%
import seaborn as sns
sns.boxplot(x='purchased', y='income', data=df)
plt.title('Income vs Purchased')
plt.show()

# %%
pd.crosstab(df['marital_status'], df['purchased']).plot(kind='bar', stacked=True)
plt.title('Marital Status vs Purchased')
plt.show()

# %%
# Convert categorical columns to numerical using one-hot encoding
df_encoded = pd.get_dummies(df, drop_first=True)
# Calculate the correlation matrix
corr = df_encoded.corr()
# Plot heatmap
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
