# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data_set=pd.read_csv('house_predict.csv')
data_set
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data_set=pd.read_csv('house_predict.csv')
#       2 data_set
#
# ...

# %%
data_set.shape
# Out:
# (1460, 2)

# %%
data_set.head()
# Out:
#     area   price
# 0   8450  208500
# 1   9600  181500
# 2  11250  223500
# 3   9550  140000
# 4  14260  250000

# %%
data_set=data_set[['area','price']]

# %%
x=data_set[['area']]
x
# Out:
#        area
# 0      8450
# 1      9600
# 2     11250
# 3      9550
# 4     14260
# ...     ...
# 1455   7917
# 1456  13175
# 1457   9042
# 1458   9717
# 1459   9937
#
# [1460 rows x 1 columns]

# %%
y=data_set[['price']]
y
# Out:
#        price
# 0     208500
# 1     181500
# 2     223500
# 3     140000
# 4     250000
# ...      ...
# 1455  175000
# 1456  210000
# 1457  266500
# 1458  142125
# 1459  147500
#
# [1460 rows x 1 columns]

# %%
plt.scatter(x,y,color='red',marker='+')
plt.xlabel('AREA(In sq feet)')
plt.ylabel('PRICE (In $)')
# Out:
# Text(0, 0.5, 'PRICE (In $)')

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
#        area
# 618   11694
# 870    6600
# 92    13360
# 817   13265
# 302   13704
# ...     ...
# 763    9430
# 835    9600
# 1216   8930
# 559    3196
# 684   16770
#
# [1168 rows x 1 columns]

# %%
y_train
# Out:
#        price
# 618   314813
# 870   109500
# 92    163500
# 817   271000
# 302   205000
# ...      ...
# 763   337000
# 835   128000
# 1216  112000
# 559   234000
# 684   221000
#
# [1168 rows x 1 columns]

# %%
x_test
# Out:
#        area
# 529   32668
# 491    9490
# 459    7015
# 279   10005
# 655    1680
# ...     ...
# 326   10846
# 440   15431
# 1387   8520
# 1323   5330
# 61     7200
#
# [292 rows x 1 columns]

# %%
y_test
# Out:
#        price
# 529   200624
# 491   133000
# 459   110000
# 279   192000
# 655    88000
# ...      ...
# 326   324000
# 440   555000
# 1387  136000
# 1323   82500
# 61    101000
#
# [292 rows x 1 columns]

# %%
x_train=np.array(x_train).reshape(len(x_train),1)
x_test=np.array(x_test).reshape(len(x_test),1)
y_train=np.array(y_train).reshape(len(y_train),1)
y_test=np.array(y_test).reshape(len(y_test),1)

# %%
x_train
# Out:
# array([[11694],
#        [ 6600],
#        [13360],
#        ...,
#        [ 8930],
#        [ 3196],
#        [16770]], dtype=int64)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
m=model.coef_
m
# Out:
# array([[1.85368175]])

# %%
c=model.intercept_
c
# Out:
# array([161179.01546459])

# %%
y_train_pred=m*x_train+c
y_train_pred
# Out:
# array([[182855.96988334],
#        [173413.31503392],
#        [185944.20368372],
#        ...,
#        [177732.39351825],
#        [167103.38234695],
#        [192265.25846121]])

# %%
y_test_pred=m*x_test+c
y_test_pred
# Out:
# array([[221735.09096926],
#        [178770.45529989],
#        [174182.59296139],
#        [179725.10140264],
#        [164293.20080951],
#        [174525.52408568],
#        [189458.78428727],
#        [177862.15124095],
#        [190139.0854906 ],
#        [170642.06081329],
#        [169020.08927948],
#        [182496.35562327],
#        [181128.33848961],
#        [175708.17304405],
#        [182800.35943075],
#        [176749.94218919],
#        [180060.61779992],
#        [176138.22721073],
#        [177016.87236162],
#        [165813.21984692],
#        [176972.38399955],
#        [169405.65508409],
#        [176883.4072754 ],
#        [176240.17970714],
#        [178084.5930513 ],
#        [193935.42572059],
#        [165103.25973554],
#        [164767.74333826],
#        [185807.031234  ],
#        [176898.23672943],
#        [182450.01357945],
#        [178449.76835663],
#        [175155.77588168],
#        [187612.51726136],
#        [183134.02214628],
# ...

# %%
plt.scatter(x_train,y_train,color='r',marker='.',label='data points')
plt.plot(x_train,y_train_pred,color='g',label='LinearRegression')
plt.xlabel('AREA(In sq feet)')
plt.ylabel('PRICE (In $)')
plt.title('Linear Regression (Training set)')  
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 plt.scatter(x_train,y_train,color='r',marker='.',label='data points')
#       2 plt.plot(x_train,y_train_pred,color='g',label='LinearRegression')
#       3 plt.xlabel('AREA(In sq feet)')
#
# NameError: name 'x_train' is not defined

# %%
plt.scatter(x_test,y_test,color='r',marker='.',label='data points')
plt.plot(x_test,y_test_pred,color='g',label='LinearRegression')
plt.xlabel('AREA(In sq feet)')
plt.ylabel('PRICE (In $)')
plt.title('Linear Regression (Testing set)')  
plt.legend()
plt.show()
