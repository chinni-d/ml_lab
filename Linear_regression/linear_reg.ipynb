# %%
import seaborn as sns

# %%
data_set=sns.load_dataset("Iris")
data_set
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data_set.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data_set.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
data_set=data_set[ ["petal_length","petal_width"]]
data_set
# Out:
#      petal_length  petal_width
# 0             1.4          0.2
# 1             1.4          0.2
# 2             1.3          0.2
# 3             1.5          0.2
# 4             1.4          0.2
# ..            ...          ...
# 145           5.2          2.3
# 146           5.0          1.9
# 147           5.2          2.0
# 148           5.4          2.3
# 149           5.1          1.8
#
# [150 rows x 2 columns]

# %%
x=data_set['petal_length']
x
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: petal_length, Length: 150, dtype: float64

# %%
y=data_set['petal_width']
y
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: petal_width, Length: 150, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y,color='red',marker='.')
plt.xlabel('petal_length')
plt.ylabel('petal_width')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=42)
x_test
# Out:
# 73     4.7
# 18     1.7
# 118    6.9
# 78     4.5
# 76     4.8
# 31     1.5
# 64     3.6
# 141    5.1
# 68     4.5
# 82     3.9
# 110    5.1
# 12     1.4
# 36     1.3
# 9      1.5
# 19     1.5
# 56     4.7
# 104    5.8
# 69     3.9
# 55     4.5
# 132    5.6
# 29     1.6
# 127    4.9
# 26     1.6
# 128    5.6
# 131    6.4
# 145    5.2
# 108    5.8
# 143    5.9
# 45     1.4
# 30     1.6
# 22     1.0
# 15     1.5
# 65     4.4
# 11     1.6
# 42     1.3
# 146    5.0
# 51     4.5
# 27     1.5
# 4      1.4
# 32     1.5
# 142    5.1
# 85     4.5
# 86     4.7
# 16     1.3
# 10     1.5
# 81     3.7
# 133    5.1
# 137    5.5
# 75     4.4
# 109    6.1
# 96     4.2
# 105    6.6
# 66     4.5
# 0      1.4
# 122    6.7
# 67     4.1
# 28     1.4
# 40     1.3
# 44     1.9
# 60     3.5
# Name: petal_length, dtype: float64

# %%
x_train
# Out:
# 123    4.9
# 24     1.9
# 25     1.6
# 23     1.7
# 94     4.2
#       ...
# 71     4.0
# 106    4.5
# 14     1.2
# 92     4.0
# 102    5.9
# Name: petal_length, Length: 90, dtype: float64

# %%
y_test
# Out:
# 73     1.2
# 18     0.3
# 118    2.3
# 78     1.5
# 76     1.4
# 31     0.4
# 64     1.3
# 141    2.3
# 68     1.5
# 82     1.2
# 110    2.0
# 12     0.1
# 36     0.2
# 9      0.1
# 19     0.3
# 56     1.6
# 104    2.2
# 69     1.1
# 55     1.3
# 132    2.2
# 29     0.2
# 127    1.8
# 26     0.4
# 128    2.1
# 131    2.0
# 145    2.3
# 108    1.8
# 143    2.3
# 45     0.3
# 30     0.2
# 22     0.2
# 15     0.4
# 65     1.4
# 11     0.2
# 42     0.2
# 146    1.9
# 51     1.5
# 27     0.2
# 4      0.2
# 32     0.1
# 142    1.9
# 85     1.6
# 86     1.5
# 16     0.4
# 10     0.2
# 81     1.0
# 133    1.5
# 137    1.8
# 75     1.4
# 109    2.5
# 96     1.3
# 105    2.1
# 66     1.5
# 0      0.2
# 122    2.0
# 67     1.0
# 28     0.2
# 40     0.3
# 44     0.4
# 60     1.0
# Name: petal_width, dtype: float64

# %%
y_train
# Out:
# 123    1.8
# 24     0.2
# 25     0.2
# 23     0.5
# 94     1.3
#       ...
# 71     1.3
# 106    1.7
# 14     0.2
# 92     1.2
# 102    2.1
# Name: petal_width, Length: 90, dtype: float64

# %%
import numpy as np

# %%
x_train=np.array(x_train).reshape(-1)
x_train
# Out:
# array([4.9, 1.9, 1.6, 1.7, 4.2, 1.5, 4.2, 6.7, 1.4, 4.3, 5. , 1.4, 4.8,
#        5.1, 4. , 4.5, 5.4, 4. , 1.7, 3.3, 5.3, 1.4, 1.2, 3.8, 5. , 1.5,
#        5.1, 1.5, 1.6, 4.8, 3. , 5.7, 5.1, 5.6, 6.1, 4. , 1.4, 1.1, 5. ,
#        6. , 1.5, 1.4, 1.3, 4.9, 5.6, 1.4, 5.5, 6. , 1.3, 4.7, 4.6, 4.8,
#        4.7, 5.3, 1.6, 5.4, 4.2, 5.2, 3.5, 3.9, 4.6, 1.3, 4.6, 4.4, 1.5,
#        4.1, 6.3, 5.7, 1.5, 3.3, 5.7, 5.8, 1.4, 5.6, 1.4, 4.9, 6.1, 5.6,
#        4.1, 5.5, 4.4, 4.3, 4.9, 5.1, 1.7, 4. , 4.5, 1.2, 4. , 5.9])

# %%
y_train=np.array(y_train).reshape(-1)
y_train
# Out:
# array([1.8, 0.2, 0.2, 0.5, 1.3, 0.2, 1.2, 2.2, 0.2, 1.3, 2. , 0.2, 1.8,
#        1.9, 1. , 1.5, 2.3, 1.3, 0.4, 1. , 1.9, 0.2, 0.2, 1.1, 1.7, 0.2,
#        2.4, 0.2, 0.6, 1.8, 1.1, 2.3, 1.6, 1.4, 2.3, 1.3, 0.2, 0.1, 1.5,
#        1.8, 0.2, 0.3, 0.2, 1.5, 2.4, 0.3, 2.1, 2.5, 0.2, 1.4, 1.5, 1.8,
#        1.4, 2.3, 0.2, 2.1, 1.5, 2. , 1. , 1.4, 1.4, 0.3, 1.3, 1.2, 0.2,
#        1.3, 1.8, 2.1, 0.4, 1. , 2.5, 1.6, 0.1, 2.4, 0.2, 1.5, 1.9, 1.8,
#        1.3, 1.8, 1.3, 1.3, 2. , 1.8, 0.2, 1.3, 1.7, 0.2, 1.2, 2.1])

# %%
x_test=np.array(x_test).reshape(-1)
x_test
# Out:
# array([4.7, 1.7, 6.9, 4.5, 4.8, 1.5, 3.6, 5.1, 4.5, 3.9, 5.1, 1.4, 1.3,
#        1.5, 1.5, 4.7, 5.8, 3.9, 4.5, 5.6, 1.6, 4.9, 1.6, 5.6, 6.4, 5.2,
#        5.8, 5.9, 1.4, 1.6, 1. , 1.5, 4.4, 1.6, 1.3, 5. , 4.5, 1.5, 1.4,
#        1.5, 5.1, 4.5, 4.7, 1.3, 1.5, 3.7, 5.1, 5.5, 4.4, 6.1, 4.2, 6.6,
#        4.5, 1.4, 6.7, 4.1, 1.4, 1.3, 1.9, 3.5])

# %%
y_test=np.array(y_test).reshape(-1)
y_test
# Out:
# array([1.2, 0.3, 2.3, 1.5, 1.4, 0.4, 1.3, 2.3, 1.5, 1.2, 2. , 0.1, 0.2,
#        0.1, 0.3, 1.6, 2.2, 1.1, 1.3, 2.2, 0.2, 1.8, 0.4, 2.1, 2. , 2.3,
#        1.8, 2.3, 0.3, 0.2, 0.2, 0.4, 1.4, 0.2, 0.2, 1.9, 1.5, 0.2, 0.2,
#        0.1, 1.9, 1.6, 1.5, 0.4, 0.2, 1. , 1.5, 1.8, 1.4, 2.5, 1.3, 2.1,
#        1.5, 0.2, 2. , 1. , 0.2, 0.3, 0.4, 1. ])

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
m=model.coef_
m
# Out:
# array([[0.42061483]])

# %%
c=model.intercept_
c
# Out:
# array([-0.373697])

# %%
y_train_pred=m*x_train+c
y_train_pred
# Out:
# array([[1.68731565],
#        [0.42547117],
#        [0.29928672],
#        [0.34134821],
#        [1.39288527],
#        [0.25722524],
#        [1.39288527],
#        [2.44442234],
#        [0.21516376],
#        [1.43494675],
#        [1.72937713],
#        [0.21516376],
#        [1.64525417],
#        [1.77143862],
#        [1.30876231],
#        [1.51906972],
#        [1.89762306],
#        [1.30876231],
#        [0.34134821],
#        [1.01433193],
#        [1.85556158],
#        [0.21516376],
#        [0.13104079],
#        [1.22463934],
#        [1.72937713],
#        [0.25722524],
#        [1.77143862],
#        [0.25722524],
#        [0.29928672],
#        [1.64525417],
#        [0.88814748],
#        [2.02380751],
#        [1.77143862],
#        [1.98174603],
#        [2.19205344],
#        [1.30876231],
#        [0.21516376],
#        [0.08897931],
#        [1.72937713],
#        [2.14999196],
#        [0.25722524],
#        [0.21516376],
#        [0.17310227],
#        [1.68731565],
#        [1.98174603],
#        [0.21516376],
#        [1.93968455],
#        [2.14999196],
#        [0.17310227],
#        [1.60319269],
#        [1.5611312 ],
#        [1.64525417],
#        [1.60319269],
#        [1.85556158],
#        [0.29928672],
#        [1.89762306],
#        [1.39288527],
#        [1.8135001 ],
#        [1.09845489],
#        [1.26670082],
#        [1.5611312 ],
#        [0.17310227],
#        [1.5611312 ],
#        [1.47700824],
#        [0.25722524],
#        [1.35082379],
#        [2.27617641],
#        [2.02380751],
#        [0.25722524],
#        [1.01433193],
#        [2.02380751],
#        [2.06586899],
#        [0.21516376],
#        [1.98174603],
#        [0.21516376],
#        [1.68731565],
#        [2.19205344],
#        [1.98174603],
#        [1.35082379],
#        [1.93968455],
#        [1.47700824],
#        [1.43494675],
#        [1.68731565],
#        [1.77143862],
#        [0.34134821],
#        [1.30876231],
#        [1.51906972],
#        [0.13104079],
#        [1.30876231],
#        [2.10793048]])

# %%
y_test_pred=m*x_test+c
y_test_pred
# Out:
# array([[1.60319269],
#        [0.34134821],
#        [2.5285453 ],
#        [1.51906972],
#        [1.64525417],
#        [0.25722524],
#        [1.14051638],
#        [1.77143862],
#        [1.51906972],
#        [1.26670082],
#        [1.77143862],
#        [0.21516376],
#        [0.17310227],
#        [0.25722524],
#        [0.25722524],
#        [1.60319269],
#        [2.06586899],
#        [1.26670082],
#        [1.51906972],
#        [1.98174603],
#        [0.29928672],
#        [1.68731565],
#        [0.29928672],
#        [1.98174603],
#        [2.31823789],
#        [1.8135001 ],
#        [2.06586899],
#        [2.10793048],
#        [0.21516376],
#        [0.29928672],
#        [0.04691783],
#        [0.25722524],
#        [1.47700824],
#        [0.29928672],
#        [0.17310227],
#        [1.72937713],
#        [1.51906972],
#        [0.25722524],
#        [0.21516376],
#        [0.25722524],
#        [1.77143862],
#        [1.51906972],
#        [1.60319269],
#        [0.17310227],
#        [0.25722524],
#        [1.18257786],
#        [1.77143862],
#        [1.93968455],
#        [1.47700824],
#        [2.19205344],
#        [1.39288527],
#        [2.40236086],
#        [1.51906972],
#        [0.21516376],
#        [2.44442234],
#        [1.35082379],
#        [0.21516376],
#        [0.17310227],
#        [0.42547117],
#        [1.09845489]])

# %%
plt.scatter(x_train,y_train,label='Data points',marker='.',color='r')
plt.plot(x_train,y_train_pred,color='g',label='RegressionLine')
plt.title('Linear Regression Line for Training Data')
plt.xlabel("petal length")
plt.ylabel("petal_width")
plt.legend()
plt.show()

# %%
plt.title('Linear Regression Line for Testing Data')
plt.scatter(x_test, y_test, label='Data points', marker='.', color='r')
plt.plot(x_test, y_test_pred, label='Regression Line', color='g')
plt.xlabel("petal length")
plt.ylabel("petal width")
plt.legend()
plt.show()
